# %% [markdown]
# # Image Classification

# %% [markdown]
# ## Libraries

# %%
import time
import datetime
import pickle
import numpy as np
from sklearn import svm, metrics
from sklearn.model_selection import StratifiedKFold,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from pandas import DataFrame

# %% [markdown]
# ## Loading Dataset from the pickle

# %%
# Start point
start_time = time.time()
print("Start time: ", datetime.datetime.now())
# Out:
# Start time:  2019-01-16 16:39:16.035625

# %%
pickle_in = open("Signature_Dataset_DAISY_110_3_int.pickle","rb")
image_dataset = pickle.load(pickle_in)

# %% [markdown]
# ## Split data in Training Set and Testing Set

# %%
X_train = image_dataset.X_train
X_test = image_dataset.X_test
y_train = image_dataset.y_train
y_test = image_dataset.y_test

print("----Dataset Loaded From Pickle----")
# Out:
# ----Dataset Loaded From Pickle----

# %% [markdown]
# ## Train data with parameter optimization

# %%
#Dictionary of models and hyperparameters

models_and_hyperparameters={'LR':(LogisticRegression(),{'C': [0.01, 0.05, 0.1, 0.5, 1, 2],
                                                        'penalty': ['l1', 'l2'], 
                                                        'class_weight': ['balanced'] }),
                           'SVM':(svm.SVC(),{'C': [1, 10, 100, 1000],
                                             'gamma': [0.001, 0.0001],
                                             'kernel': ['rbf'],
                                             'class_weight': ['balanced']}),
                           'RFC':(RandomForestClassifier(), {'n_estimators': [50,100,200],
                                                             # 'max_features': ['auto', 'sqrt'],
                                                             'max_depth': [50,60,70],
                                                             'min_samples_split': [2,5,10],
                                                             #'min_samples_leaf': [1,2],
                                                             'bootstrap': [True, False],
                                                             'class_weight': ['balanced']})
                           }

# %% [markdown]
# # Logistic Regression

# %%
#LOGISTIC REGRESSION

print("----Training----")

k_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=31)

model = models_and_hyperparameters['LR'][0]
hyperparameters = models_and_hyperparameters['LR'][1]

gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='roc_auc',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
# Out:
# ----Training----
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   1.0s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.1s remaining:    0.0s
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   1.0s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   1.0s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.9s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.9s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.9s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.9s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.9s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   1.0s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   1.0s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6022038567493113, total=   1.3s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.5636363636363637, total=   1.4s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6476584022038567, total=   1.5s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6528007346189165, total=   1.3s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.5451790633608815, total=   1.6s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.5696969696969697, total=   1.3s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.5425160697887971, total=   1.3s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6480257116620753, total=   1.4s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.5743801652892563, total=   1.4s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6107438016528927, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.3s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.6205693296602388, total=   2.0s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.5892561983471074, total=   2.3s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.660514233241506, total=   2.2s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.676216712580349, total=   2.3s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.5470156106519743, total=   2.0s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.5842056932966023, total=   1.9s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.580532598714417, total=   1.9s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.6577594123048669, total=   2.0s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.6025711662075298, total=   2.0s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.621763085399449, total=   2.1s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5, total=   1.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6348943985307621, total=   2.3s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6059687786960515, total=   2.3s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6658402203856749, total=   2.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6889807162534436, total=   2.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.5547291092745639, total=   2.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.594674012855831, total=   2.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6000918273645546, total=   2.3s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6641873278236915, total=   2.3s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6189164370982553, total=   1.8s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6295684113865933, total=   2.2s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.4963269054178145, total=   1.9s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.5254361799816346, total=   1.9s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.5368227731864096, total=   2.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.5940312213039486, total=   1.7s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=
class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.6581267217630854, total=   4.4s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.6970615243342516, total=   4.5s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  4.7min finished
# ----Training Ended----

# %%
DataFrame(gs.cv_results_)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0        0.946181         0.009711         0.500000          0.500000    0.01
# 1        1.372397         0.003800         0.595684          0.643196    0.01
# 2        1.207217         0.003725         0.500000          0.500000    0.05
# 3        2.078948         0.004346         0.614040          0.661744    0.05
# 4        1.180818         0.003749         0.500000          0.500000     0.1
# 5        2.190995         0.003585         0.625785          0.674796     0.1
# 6        1.963071         0.003753         0.541690          0.543274     0.5
# 7        3.300158         0.003576         0.658733          0.718044     0.5
# 8        2.444153         0.003769         0.555308          0.582827       1
# 9        3.655536         0.003576         0.674086          0.741410       1
# 10       2.476216         0.003855         0.641249          0.671564       2
# 11       4.871757         0.003581         0.690661          0.767342       2
#
#    param_class_weight param_penalty  \
# 0            balanced            l1
# 1            balanced            l2
# 2            balanced            l1
# 3            balanced            l2
# 4            balanced            l1
# 5            balanced            l2
# 6            balanced            l1
# 7            balanced            l2
# 8            balanced            l1
# 9            balanced            l2
# 10           balanced            l1
# 11           balanced            l2
#
#                                                params  rank_test_score  \
# 0   {'C': 0.01, 'class_weight': 'balanced', 'penal...               10
# 1   {'C': 0.01, 'class_weight': 'balanced', 'penal...                7
# 2   {'C': 0.05, 'class_weight': 'balanced', 'penal...               10
# 3   {'C': 0.05, 'class_weight': 'balanced', 'penal...                6
# 4   {'C': 0.1, 'class_weight': 'balanced', 'penalt...               10
# 5   {'C': 0.1, 'class_weight': 'balanced', 'penalt...                5
# 6   {'C': 0.5, 'class_weight': 'balanced', 'penalt...                9
# 7   {'C': 0.5, 'class_weight': 'balanced', 'penalt...                3
# 8   {'C': 1, 'class_weight': 'balanced', 'penalty'...                8
# 9   {'C': 1, 'class_weight': 'balanced', 'penalty'...                2
# 10  {'C': 2, 'class_weight': 'balanced', 'penalty'...                4
# 11  {'C': 2, 'class_weight': 'balanced', 'penalty'...                1
#
#     split0_test_score       ...         split7_test_score  split7_train_score  \
# 0            0.500000       ...                  0.500000            0.500000
# 1            0.602204       ...                  0.648026            0.638755
# 2            0.500000       ...                  0.500000            0.500000
# 3            0.620569       ...                  0.657759            0.658226
# 4            0.500000       ...                  0.500000            0.500000
# 5            0.634894       ...                  0.664187            0.671623
# 6            0.496327       ...                  0.547107            0.542225
# 7            0.666758       ...                  0.694582            0.715023
# 8            0.555280       ...                  0.567401            0.567555
# 9            0.680716       ...                  0.711846            0.738100
# 10           0.641965       ...                  0.660239            0.670096
# 11           0.693480       ...                  0.725620            0.764263
#
#     split8_test_score  split8_train_score  split9_test_score  \
# 0            0.500000            0.500000           0.500000
# 1            0.574380            0.640721           0.610744
# 2            0.500000            0.500000           0.500000
# 3            0.602571            0.660876           0.621763
# 4            0.500000            0.500000           0.500000
# 5            0.618916            0.675233           0.629568
# 6            0.519467            0.545555           0.568687
# 7            0.642241            0.721813           0.656474
# 8            0.556198            0.596791           0.579890
# 9            0.649311            0.745669           0.676217
# 10           0.598714            0.671867           0.640771
# 11           0.658127            0.771013           0.697062
#
#     split9_train_score  std_fit_time  std_score_time  std_test_score  \
# 0             0.500000      0.040070        0.017649        0.000000
# 1             0.647974      0.111126        0.000488        0.040628
# 2             0.500000      0.025878        0.000041        0.000000
# 3             0.663724      0.140061        0.001627        0.039103
# 4             0.500000      0.006263        0.000028        0.000000
# 5             0.675327      0.127370        0.000023        0.037798
# 6             0.540414      0.132424        0.000012        0.029943
# 7             0.716261      0.337687        0.000012        0.030374
# 8             0.586202      0.358026        0.000028        0.029331
# 9             0.739423      0.241704        0.000014        0.027481
# 10            0.674991      0.288524        0.000179        0.049110
# 11            0.765301      0.429633        0.000031        0.026443
#
#     std_train_score
# 0          0.000000
# 1          0.005479
# 2          0.000000
# 3          0.003574
# 4          0.000000
# 5          0.002882
# 6          0.003266
# 7          0.002559
# 8          0.018901
# 9          0.002591
# 10         0.005312
# 11         0.002515
#
# [12 rows x 33 columns]

# %%
# Creation of the pickle which is goig to store the model.

pickle_out = open("LR_roc_auc_DAISY_3.pickle","wb") #Modify with the name of the dataset you're saving
pickle.dump(gs.cv_results_, pickle_out)
pickle_out.close()

print("----Pickle created----")
# Out:
# ----Pickle created----

# %% [markdown]
# ### Predict

# %%
y_pred = gs.predict(X_test)

# %%
print("Best hyperparameters: {}".format(gs.best_params_))
print("Best roc_auc score: {:3f}".format(gs.best_score_))
# Out:
# Best hyperparameters: {'C': 2, 'class_weight': 'balanced', 'penalty': 'l2'}
# Best roc_auc score: 0.690661

# %% [markdown]
# ### Report

# %% [raw]
# print("Classification report for - \n{}:\n{}\n".format(gs, metrics.classification_report(y_test, y_pred)))

# %% [markdown]
# \\
# \\
# \\
# \\
# \\
# # SVM

# %%
# SVM

print("----Training----")

k_fold = StratifiedKFold(n_splits=4, shuffle=True, random_state=31)

model = models_and_hyperparameters['SVM'][0]
hyperparameters = models_and_hyperparameters['SVM'][1]

gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='roc_auc',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
# Out:
# ----Training----
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.5684310850439882, total= 1.2min
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.2min remaining:    0.0s
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6141055718475072, total= 1.2min
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  4.3min remaining:    0.0s
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.5433640044166359, total= 1.2min
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.601648877438351, total= 1.3min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5681378299120234, total= 1.2min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6141202346041056, total= 1.2min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5433051159366948, total= 1.3min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.601324990798675, total= 1.3min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.5684310850439882, total= 1.2min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6141055718475072, total= 1.2min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.5433640044166359, total= 1.2min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.601648877438351, total= 1.2min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5681378299120234, total= 1.2min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6141202346041056, total= 1.2min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5433051159366948, total= 1.2min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.601324990798675, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6149853372434018, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6422140762463344, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6099521531100478, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6326978284873022, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5681378299120234, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6141202346041056, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5433051159366948, total= 1.2min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.601324990798675, total= 1.2min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.699076246334311, total= 1.1min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.7021994134897361, total= 1.1min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6690025763709975, total= 1.1min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6995509753404491, total= 1.1min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.614633431085044, total= 1.2min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6420821114369502, total= 1.2min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6097902097902098, total= 1.2min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6324475524475525, total= 1.2min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 66.9min finished
# ----Training Ended----

# %%
DataFrame(gs.cv_results_)
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0      55.831800        18.500885         0.581896          0.634364       1
# 1      56.768690        18.975788         0.581731          0.634216       1
# 2      55.044163        18.266336         0.581896          0.634364      10
# 3      55.195572        18.371802         0.581731          0.634216      10
# 4      53.262908        17.545612         0.624966          0.679156     100
# 5      54.672679        18.174279         0.581731          0.634216     100
# 6      48.423498        15.470352         0.692465          0.784700    1000
# 7      53.206612        17.495161         0.624742          0.678943    1000
#
#   param_class_weight param_gamma param_kernel  \
# 0           balanced       0.001          rbf
# 1           balanced      0.0001          rbf
# 2           balanced       0.001          rbf
# 3           balanced      0.0001          rbf
# 4           balanced       0.001          rbf
# 5           balanced      0.0001          rbf
# 6           balanced       0.001          rbf
# 7           balanced      0.0001          rbf
#
#                                               params  rank_test_score  \
# 0  {'C': 1, 'class_weight': 'balanced', 'gamma': ...                4
# 1  {'C': 1, 'class_weight': 'balanced', 'gamma': ...                6
# 2  {'C': 10, 'class_weight': 'balanced', 'gamma':...                4
# 3  {'C': 10, 'class_weight': 'balanced', 'gamma':...                6
# 4  {'C': 100, 'class_weight': 'balanced', 'gamma'...                2
# 5  {'C': 100, 'class_weight': 'balanced', 'gamma'...                6
# 6  {'C': 1000, 'class_weight': 'balanced', 'gamma...                1
# 7  {'C': 1000, 'class_weight': 'balanced', 'gamma...                3
#
#         ...         split1_test_score  split1_train_score  split2_test_score  \
# 0       ...                  0.614106            0.637373           0.543364
# 1       ...                  0.614120            0.637272           0.543305
# 2       ...                  0.614106            0.637373           0.543364
# 3       ...                  0.614120            0.637272           0.543305
# 4       ...                  0.642214            0.675539           0.609952
# 5       ...                  0.614120            0.637272           0.543305
# 6       ...                  0.702199            0.781575           0.669003
# 7       ...                  0.642082            0.675277           0.609790
#
#    split2_train_score  split3_test_score  split3_train_score  std_fit_time  \
# 0            0.635972           0.601649            0.629794      0.807686
# 1            0.635755           0.601325            0.629650      0.958382
# 2            0.635972           0.601649            0.629794      0.492905
# 3            0.635755           0.601325            0.629650      0.369913
# 4            0.693030           0.632698            0.671073      0.129788
# 5            0.635755           0.601325            0.629650      0.027076
# 6            0.793352           0.699551            0.781177      0.077503
# 7            0.692805           0.632448            0.670822      0.188395
#
#    std_score_time  std_test_score  std_train_score
# 0        0.296982        0.027807         0.002852
# 1        0.515612        0.027811         0.002853
# 2        0.046947        0.027807         0.002852
# 3        0.256913        0.027811         0.002853
# 4        0.078148        0.013062         0.008301
# 5        0.017069        0.027811         0.002853
# 6        0.062799        0.013590         0.005026
# 7        0.047116        0.013095         0.008304
#
# [8 rows x 22 columns]

# %%
# Creation of the pickle which is goig to store the model.

pickle_out = open("SVM_roc_auc_DAISY_3.pickle","wb") #Modify with the name of the dataset you're saving
pickle.dump(gs.cv_results_, pickle_out)
pickle_out.close()

print("----Pickle created----")
# Out:
# ----Pickle created----

# %% [markdown]
# ### Predict

# %%
y_pred = gs.predict(X_test)

# %%
print("Best hyperparameters: {}".format(gs.best_params_))
print("Best roc_auc score: {:3f}".format(gs.best_score_))
# Out:
# Best hyperparameters: {'C': 1000, 'class_weight': 'balanced', 'gamma': 0.001, 'kernel': 'rbf'}
# Best roc_auc score: 0.692465

# %% [markdown]
# ### Report

# %%
print("Classification report for - \n{}:\n{}\n".format(gs, metrics.classification_report(y_test, y_pred)))
# Out:
# Classification report for -
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=31, shuffle=True),
#        error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf'], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=3):
#              precision    recall  f1-score   support
#
#          -1       0.60      0.59      0.59       480
#           1       0.55      0.57      0.56       432
#
# avg / total       0.58      0.58      0.58       912

# %% [markdown]
# //
# //
# //
# //
# //
#
# # Random Forest

# %%
#RANDOM FOREST

print("----Training----")

k_fold = StratifiedKFold(n_splits=4, shuffle=True, random_state=31)

model = models_and_hyperparameters['RFC'][0]
hyperparameters = models_and_hyperparameters['RFC'][1]

gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='roc_auc',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
# Out:
# ----Training----
# Fitting 4 folds for each of 54 candidates, totalling 216 fits
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.9050586510263929, total=   4.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.3s remaining:    0.0s
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.9062316715542521, total=   4.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    8.6s remaining:    0.0s
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.8953698932646301, total=   4.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=
# 21       4.156645         0.026334         0.899463          1.000000
# 22       8.218346         0.034943         0.908656          1.000000
# 23      16.383828         0.053367         0.913930          1.000000
# 24       4.153390         0.026257         0.893575          0.999998
# 25       8.156929         0.034708         0.906640          1.000000
# 26      16.260590         0.055083         0.910086          1.000000
# 27       6.719623         0.026966         0.925717          1.000000
# 28      13.252678         0.036267         0.926924          1.000000
# 29      26.222678         0.055839         0.930732          1.000000
# 30       6.615112         0.026782         0.916856          1.000000
# 31      13.243246         0.035877         0.925468          1.000000
# 32      25.958395         0.054828         0.926944          1.000000
# 33       6.579883         0.026308         0.918598          1.000000
# 34      12.993492         0.035151         0.922665          1.000000
# 35      25.878334         0.053808         0.925394          1.000000
# 36       6.666640         0.026499         0.919012          1.000000
# 37      13.151888         0.035505         0.924969          1.000000
# 38      26.235862         0.054817         0.927459          1.000000
# 39       6.598020         0.026426         0.921650          1.000000
# 40      13.012858         0.035497         0.926728          1.000000
# 41      26.005479         0.053867         0.928400          1.000000
# 42       6.608699         0.026245         0.918539          1.000000
# 43      13.229600         0.035576         0.923456          1.000000
# 44      27.067865         0.057266         0.924836          1.000000
# 45       6.795345         0.028281         0.916804          1.000000
# 46      14.068016         0.036511         0.925133          1.000000
# 47      27.231124         0.059555         0.927035          1.000000
# 48       6.743792         0.027047         0.920133          1.000000
# 49      13.211703         0.036137         0.925811          1.000000
# 50      26.389754         0.056118         0.928357          1.000000
# 51       6.566455         0.026751         0.916943          1.000000
# 52      13.036775         0.035835         0.923270          1.000000
# 53      26.092228         0.055122         0.923940          1.000000
#
#    param_bootstrap param_class_weight param_max_depth param_min_samples_split  \
# 0             True           balanced              50                       2
# 1             True           balanced              50                       2
# 2             True           balanced              50                       2
# 3             True           balanced              50                       5
# 4             True           balanced              50                       5
# 5             True           balanced              50                       5
# 6             True           balanced              50                      10
# 7             True           balanced              50                      10
# 8             True           balanced              50                      10
# 9             True           balanced              60                       2
# 10            True           balanced              60                       2
# 11            True           balanced              60                       2
# 12            True           balanced              60                       5
# 13            True           balanced              60                       5
# 14            True           balanced              60                       5
# 15            True           balanced              60                      10
# 16            True           balanced              60                      10
# 17            True           balanced              60                      10
# 18            True           balanced              70                       2
# 19            True           balanced              70                       2
# 20            True           balanced              70                       2
# 21            True           balanced              70                       5
# 22            True           balanced              70                       5
# 23            True           balanced              70                       5
# 24            True           balanced              70                      10
# 25            True           balanced              70                      10
# 26            True           balanced              70                      10
# 27           False           balanced              50                       2
# 28           False           balanced              50                       2
# 29           False           balanced              50                       2
# 30           False           balanced              50                       5
# 31           False           balanced              50                       5
# 32           False           balanced              50                       5
# 33           False           balanced              50                      10
# 34           False           balanced              50                      10
# 35           False           balanced              50                      10
# 36           False           balanced              60                       2
# 37           False           balanced              60                       2
# 38           False           balanced              60                       2
# 39           False           balanced              60                       5
# 40           False           balanced              60                       5
# 41           False           balanced              60                       5
# 42           False           balanced              60                      10
# 43           False           balanced              60                      10
# 44           False           balanced              60                      10
# 45           False           balanced              70                       2
# 46           False           balanced              70                       2
# 47           False           balanced              70                       2
# 48           False           balanced              70                       5
# 49           False           balanced              70                       5
# 50           False           balanced              70                       5
# 51           False           balanced              70                      10
# 52           False           balanced              70                      10
# 53           False           balanced              70                      10
#
#    param_n_estimators                                             params  \
# 0                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 1                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 2                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 3                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 4                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 5                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 6                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 7                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 8                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 9                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 10                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 11                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 12                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 13                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 14                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 15                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 16                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 17                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 18                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 19                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 20                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 21                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 22                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 23                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 24                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 25                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 26                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 27                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 28                100  {'bootstrap': False, 'class_weight': 'balanced...
# 29                200  {'bootstrap': False, 'class_weight': 'balanced...
# 30                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 31                100  {'bootstrap': False, 'class_weight': 'balanced...
# 32                200  {'bootstrap': False, 'class_weight': 'balanced...
# 33                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 34                100  {'bootstrap': False, 'class_weight': 'balanced...
# 35                200  {'bootstrap': False, 'class_weight': 'balanced...
# 36                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 37                100  {'bootstrap': False, 'class_weight': 'balanced...
# 38                200  {'bootstrap': False, 'class_weight': 'balanced...
# 39                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 40                100  {'bootstrap': False, 'class_weight': 'balanced...
# 41                200  {'bootstrap': False, 'class_weight': 'balanced...
# 42                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 43                100  {'bootstrap': False, 'class_weight': 'balanced...
# 44                200  {'bootstrap': False, 'class_weight': 'balanced...
# 45                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 46                100  {'bootstrap': False, 'class_weight': 'balanced...
# 47                200  {'bootstrap': False, 'class_weight': 'balanced...
# 48                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 49                100  {'bootstrap': False, 'class_weight': 'balanced...
# 50                200  {'bootstrap': False, 'class_weight': 'balanced...
# 51                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 52                100  {'bootstrap': False, 'class_weight': 'balanced...
# 53                200  {'bootstrap': False, 'class_weight': 'balanced...
#
#          ...         split1_test_score  split1_train_score  split2_test_score  \
# 0        ...                  0.906232            1.000000           0.895370
# 1        ...                  0.929260            1.000000           0.907081
# 2        ...                  0.921122            1.000000           0.912256
# 3        ...                  0.914435            1.000000           0.900729
# 4        ...                  0.924062            1.000000           0.908046
# 5        ...                  0.926085            1.000000           0.912330
# 6        ...                  0.899985            1.000000           0.898579
# 7        ...                  0.913211            1.000000           0.901715
# 8        ...                  0.918343            1.000000           0.913758
# 9        ...                  0.897023            1.000000           0.901980
# 10       ...                  0.926232            1.000000           0.909960
# 11       ...                  0.925403            1.000000           0.912477
# 12       ...                  0.922742            1.000000           0.895812
# 13       ...                  0.914971            1.000000           0.906515
# 14       ...                  0.922595            1.000000           0.915789
# 15       ...                  0.906804            1.000000           0.897343
# 16       ...                  0.917287            1.000000           0.910151
# 17       ...                  0.921891            1.000000           0.906765
# 18       ...                  0.914311            1.000000           0.887751
# 19       ...                  0.913248            1.000000           0.910217
# 20       ...                  0.927705            1.000000           0.913927
# 21       ...                  0.909787            1.000000           0.890512
# 22       ...                  0.906686            1.000000           0.909856
# 23       ...                  0.915543            1.000000           0.911476
# 24       ...                  0.901085            0.999993           0.889658
# 25       ...                  0.923211            1.000000           0.901303
# 26       ...                  0.918299            1.000000           0.902863
# 27       ...                  0.932742            1.000000           0.925992
# 28       ...                  0.932940            1.000000           0.927957
# 29       ...                  0.937119            1.000000           0.935576
# 30       ...                  0.919091            1.000000           0.923393
# 31       ...                  0.929883            1.000000           0.932661
# 32       ...                  0.931979            1.000000           0.931299
# 33       ...                  0.922346            1.000000           0.924741
# 34       ...                  0.920718            1.000000           0.927302
# 35       ...                  0.929472            1.000000           0.928141
# 36       ...                  0.918548            1.000000           0.922694
# 37       ...                  0.930301            1.000000           0.930401
# 38       ...                  0.930235            1.000000           0.931807
# 39       ...                  0.928666            1.000000           0.925705
# 40       ...                  0.930477            1.000000           0.931844
# 41       ...                  0.932419            1.000000           0.932160
# 42       ...                  0.920000            1.000000           0.924902
# 43       ...                  0.926760            1.000000           0.926978
# 44       ...                  0.926628            1.000000           0.930085
# 45       ...                  0.925594            1.000000           0.916238
# 46       ...                  0.923585            1.000000           0.928208
# 47       ...                  0.934157            1.000000           0.926816
# 48       ...                  0.921730            1.000000           0.924107
# 49       ...                  0.929164            1.000000           0.931174
# 50       ...                  0.934179            1.000000           0.935149
# 51       ...                  0.918534            1.000000           0.921178
# 52       ...                  0.929707            1.000000           0.927494
# 53       ...                  0.931070            1.000000           0.927685
#
#     split2_train_score  split3_test_score  split3_train_score  std_fit_time  \
# 0                  1.0           0.878565                 1.0      0.024908
# 1                  1.0           0.899168                 1.0      0.150211
# 2                  1.0           0.901524                 1.0      0.130817
# 3                  1.0           0.890843                 1.0      0.066610
# 16        0.000062        0.009499     0.000000e+00
# 17        0.000167        0.009202     0.000000e+00
# 18        0.000086        0.011072     0.000000e+00
# 19        0.000074        0.004088     0.000000e+00
# 20        0.000255        0.008321     0.000000e+00
# 21        0.000100        0.007739     0.000000e+00
# 22        0.000080        0.013185     5.551115e-17
# 23        0.000113        0.006803     0.000000e+00
# 24        0.000057        0.007946     2.829455e-06
# 25        0.000081        0.012351     0.000000e+00
# 26        0.003982        0.007388     0.000000e+00
# 27        0.000041        0.008370     0.000000e+00
# 28        0.000086        0.006632     0.000000e+00
# 29        0.000238        0.007469     0.000000e+00
# 30        0.000063        0.005012     0.000000e+00
# 31        0.000052        0.009494     0.000000e+00
# 32        0.000494        0.006610     0.000000e+00
# 33        0.000046        0.006903     0.000000e+00
# 34        0.000086        0.004890     0.000000e+00
# 35        0.000048        0.007695     0.000000e+00
# 36        0.000072        0.002811     0.000000e+00
# 37        0.000126        0.006677     0.000000e+00
# 38        0.000170        0.005301     0.000000e+00
# 39        0.000103        0.006026     5.551115e-17
# 40        0.000190        0.007998     0.000000e+00
# 41        0.000762        0.006041     0.000000e+00
# 42        0.000077        0.004932     0.000000e+00
# 43        0.000257        0.006039     0.000000e+00
# 44        0.000432        0.004971     0.000000e+00
# 45        0.001002        0.007065     0.000000e+00
# 46        0.000300        0.006956     0.000000e+00
# 47        0.003466        0.005601     0.000000e+00
# 48        0.000130        0.005024     0.000000e+00
# 49        0.000068        0.005290     0.000000e+00
# 50        0.000121        0.007669     0.000000e+00
# 51        0.000022        0.008065     0.000000e+00
# 52        0.000061        0.009276     0.000000e+00
# 53        0.000183        0.007283     0.000000e+00
#
# [54 rows x 23 columns]

# %%
# Creation of the pickle which is goig to store the model.

pickle_out = open("RF_roc_auc_DAISY_3.pickle","wb") #Modify with the name of the dataset you're saving
pickle.dump(gs.cv_results_, pickle_out)
pickle_out.close()

print("----Pickle created----")
# Out:
# ----Pickle created----

# %% [markdown]
# ## Predict

# %%
y_pred = gs.predict(X_test)

# %%
print("Best hyperparameters: {}".format(gs.best_params_))
print("Best roc_auc score: {:3f}".format(gs.best_score_))
# Out:
# Best hyperparameters: {'bootstrap': False, 'class_weight': 'balanced', 'max_depth': 50, 'min_samples_split': 2, 'n_estimators': 200}
# Best roc_auc score: 0.930732

# %% [markdown]
# ## Report

# %%
print("Classification report for - \n{}:\n{}\n".format(gs, metrics.classification_report(y_test, y_pred)))
# Out:
# Classification report for -
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=31, shuffle=True),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [50, 100, 200], 'max_depth': [50, 60, 70], 'min_samples_split': [2, 5, 10], 'bootstrap': [True, False], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=3):
#              precision    recall  f1-score   support
#
#          -1       0.60      0.65      0.63       480
#           1       0.58      0.52      0.55       432
#
# avg / total       0.59      0.59      0.59       912

# %%
# End point
end_time = time.time()
uptime = end_time - start_time
human_uptime = datetime.timedelta(seconds=uptime)

print("End time: ", datetime.datetime.now())
print("Uptime :" ,human_uptime)
# Out:
# End time:  2019-01-16 18:39:19.367414
# Uptime : 2:00:03.331741
