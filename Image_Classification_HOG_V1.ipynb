# %% [markdown]
# # Image Classification using `sklearn.svm`

# %% [markdown]
# ## Libraries

# %%
import numpy as np
from sklearn import svm, metrics
from sklearn.model_selection import GridSearchCV, train_test_split

import time
import datetime

# My addition to the original code
import pickle

# %% [markdown]
# ## Loading Dataset from the pickle

# %%
# Start point
start_time = time.time()
print("Start time: ", datetime.datetime.now())
# Out:
# Start time:  2019-01-14 07:26:26.477670

# %%
pickle_in = open("Signature_Dataset_HOG_V1.pickle","rb")
image_dataset = pickle.load(pickle_in)

# %% [markdown]
# ### Split data in Training Set and Testing Set

# %%
# Manual splitting of the Dataset
ds70=(70*158)//100*(20-2)
# 70%dataset_index = [70%(number_of_subjects)]*(20-number_of_fixed_genuine_signatures)
# [ ] = floor of a number


X_train = image_dataset.data[:ds70]
X_test = image_dataset.data[ds70:]
y_train = image_dataset.target[:ds70]
y_test = image_dataset.target[ds70:]

print("----Dataset Splitted----")
# Out:
# ----Dataset Splitted----

# %% [markdown]
# ### Train data with parameter optimization

# %%
from pandas import DataFrame
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
#Dictionary of models and hyperparameters
models_and_hyperparameters={'LR':(LogisticRegression(),{'C': [0.01, 0.05, 0.1, 0.5, 1, 2],
                                                        'penalty': ['l1', 'l2'], 
                                                        'class_weight': ['balanced']}),
                           'SVM':(svm.SVC(),{'C': [1, 10, 100, 1000],
                                             'gamma': [0.001, 0.0001],
                                             'kernel': ['rbf'],
                                             'class_weight': ['balanced']}),
                           'RFC':(RandomForestClassifier(), {'n_estimators': [50,100,200],
                                                             # 'max_features': ['auto', 'sqrt'],
                                                             'max_depth': [50,60,70],
                                                             'min_samples_split': [2,5,10],
                                                             #'min_samples_leaf': [1,2],
                                                             'bootstrap': [True, False],
                                                             'class_weight': ['balanced']})
                           }

# %%
#LOGISTIC REGRESSION
"""
print("----Training----")

k_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=31)

model = models_and_hyperparameters['LR'][0]

hyperparameters = models_and_hyperparameters['LR'][1]


gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='accuracy',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
"""
# Out:
# '\nprint("----Training----")\n\nk_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=31)\n\nmodel = models_and_hyperparameters[\'LR\'][0]\n\nhyperparameters = models_and_hyperparameters[\'LR\'][1]\n\n\ngs = GridSearchCV(model, \n                   param_grid = hyperparameters,\n                   cv=k_fold, \n                   scoring=\'accuracy\',\n                   verbose=3,\n                   return_train_score=True)\n\ngs.fit(X_train, y_train)\n\nprint("----Training Ended----")\n'

# %%
# SVM
"""
print("----Training----")

k_fold = StratifiedKFold(n_splits=4, shuffle=True, random_state=31)

model = models_and_hyperparameters['SVM'][0]

hyperparameters = models_and_hyperparameters['SVM'][1]


gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='accuracy',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
"""
# Out:
# '\nprint("----Training----")\n\nk_fold = StratifiedKFold(n_splits=4, shuffle=True, random_state=31)\n\nmodel = models_and_hyperparameters[\'SVM\'][0]\n\nhyperparameters = models_and_hyperparameters[\'SVM\'][1]\n\n\ngs = GridSearchCV(model, \n                   param_grid = hyperparameters,\n                   cv=k_fold, \n                   scoring=\'accuracy\',\n                   verbose=3,\n                   return_train_score=True)\n\ngs.fit(X_train, y_train)\n\nprint("----Training Ended----")\n'

# %%
# RANDOM FOREST

print("----Training----")

k_fold = StratifiedKFold(n_splits=4, shuffle=True, random_state=31)

model = models_and_hyperparameters['RFC'][0]

hyperparameters = models_and_hyperparameters['RFC'][1]


gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='accuracy',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
# Out:
# ----Training----
# Fitting 4 folds for each of 54 candidates, totalling 216 fits
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.6868686868686869, total=   7.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.5s remaining:    0.0s
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.6787878787878788, total=   6.5s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   15.4s remaining:    0.0s
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.692929292929293, total=   6.6s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.7212121212121212, total=   6.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.7070707070707071, total=  11.6s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.6989898989898989, total=  11.7s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.6989898989898989, total=  11.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.7131313131313132, total=  11.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.7313131313131314, total=  21.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.701010101010101, total=  21.6s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.7151515151515152, total=  21.8s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.7292929292929293, total=  21.7s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.6828282828282828, total=   5.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.7090909090909091, total=   6.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.6727272727272727, total=   6.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.696969696969697, total=   6.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.7131313131313132, total=  11.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.7090909090909091, total=  11.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.6686868686868687, total=  11.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.7353535353535353, total=  11.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.7252525252525253, total=  21.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.7414141414141414, total=  22.6s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.7151515151515152, total=  21.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.7232323232323232, total=  21.5s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.6767676767676768, total=   5.8s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.6808080808080809, total=   6.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.6666666666666666, total=   6.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.6888888888888889, total=   6.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.7191919191919192, total=  10.8s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.7131313131313132, total=  11.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.6909090909090909, total=  11.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.7131313131313132, total=  11.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200, score=0.7111111111111111, total=  20.8s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200, score=0.7232323232323232, total=  21.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200, score=0.7171717171717171, total=  20.7s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200, score=0.701010101010101, total=  21.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50, score=0.6909090909090909, total=   6.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50, score=0.6909090909090909, total=   6.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50, score=0.6444444444444445, total=   6.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=50, score=0.7151515151515152, total=   6.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100, score=0.692929292929293, total=  11.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100, score=0.6868686868686869, total=  11.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100, score=0.6888888888888889, total=  11.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=100, score=0.7232323232323232, total=  11.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200, score=0.7252525252525253, total=  21.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200, score=0.7171717171717171, total=  21.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200, score=0.703030303030303, total=  21.6s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=2, n_estimators=200, score=0.7232323232323232, total=  21.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50, score=0.7252525252525253, total=   5.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50, score=0.6868686868686869, total=   6.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50, score=0.6767676767676768, total=   6.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=50, score=0.7272727272727273, total=   5.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100, score=0.694949494949495, total=  11.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100, score=0.703030303030303, total=  11.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100, score=0.7070707070707071, total=  11.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=100, score=0.7252525252525253, total=  11.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=200, score=0.7191919191919192, total=  21.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=60, min_samples_split=5, n_estimators=
cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        6.583638      0.500548         0.220798        0.182865
# 1       11.373590      0.150671         0.120821        0.002678
# 2       21.479920      0.128142         0.142217        0.000252
# 3        5.936680      0.100051         0.107549        0.000096
# 4       11.044159      0.140344         0.118931        0.000239
# 5       21.629237      0.526490         0.142313        0.000801
# 6        5.881667      0.132362         0.107572        0.000228
# 7       10.846113      0.124563         0.118649        0.000127
# 8       20.862422      0.231569         0.140942        0.000122
# 9        5.964121      0.055011         0.107661        0.000130
# 10      11.119665      0.060761         0.119119        0.000132
# 11      21.363466      0.251090         0.143357        0.002776
# 12       5.931751      0.100760         0.107599        0.000145
# 13      10.981060      0.050724         0.118865        0.000211
# 14      21.153015      0.138853         0.141887        0.000268
# 15       5.845760      0.065542         0.107459        0.000131
# 16      10.836288      0.115407         0.120210        0.002304
# 17      20.712257      0.058066         0.141155        0.000275
# 18       6.018938      0.122793         0.107770        0.000127
# 19      11.144369      0.022375         0.119098        0.000295
# 20      21.449518      0.162308         0.142079        0.000295
# 21       5.945787      0.076535         0.119343        0.020272
# 22      11.060879      0.160974         0.118874        0.000097
# 23      21.144120      0.128106         0.141785        0.000077
# 24       5.834602      0.113864         0.107679        0.000081
# 25      10.824755      0.155766         0.118790        0.000200
# 26      21.115864      0.292502         0.141007        0.000102
# 27       9.527209      0.152875         0.108266        0.000084
# 28      18.155601      0.296146         0.120223        0.000122
# 29      35.739531      0.465848         0.144636        0.000206
# 30       9.484552      0.138838         0.108360        0.000221
# 31      18.107119      0.327871         0.120681        0.000559
# 32      36.561112      1.550194         0.145880        0.001313
# 33      10.124439      0.188126         0.108949        0.000493
# 34      19.548322      0.438263         0.121354        0.000242
# 35      38.498819      0.864840         0.146178        0.000430
# 36      10.490038      0.199562         0.108794        0.000086
# 37      19.961464      0.488925         0.121398        0.000118
# 38      39.354363      0.452595         0.146929        0.000265
# 39      10.189310      0.156433         0.108766        0.000072
# 40      19.919091      0.327475         0.121513        0.000336
# 41      39.206071      0.821220         0.146407        0.000551
# 42      10.344427      0.186195         0.108716        0.000199
# 43      19.929940      0.233105         0.121156        0.000108
# 44      39.533480      1.203230         0.146939        0.001474
# 45      10.454361      0.248613         0.109455        0.000079
# 46      20.257809      0.361059         0.122401        0.001077
# 47      38.450251      1.579450         0.154795        0.013483
# 48       9.348503      0.228249         0.108420        0.000237
# 49      18.882384      0.985326         0.121264        0.000830
# 50      39.062013      0.553167         0.146444        0.000218
# 51      10.251583      0.274954         0.108900        0.000157
# 52      19.706616      0.437623         0.121223        0.000102
# 53      38.574041      0.648619         0.146080        0.000317
#
#    param_bootstrap param_class_weight param_max_depth param_min_samples_split  \
# 0             True           balanced              50                       2
# 1             True           balanced              50                       2
# 2             True           balanced              50                       2
# 3             True           balanced              50                       5
# 4             True           balanced              50                       5
# 5             True           balanced              50                       5
# 6             True           balanced              50                      10
# 7             True           balanced              50                      10
# 8             True           balanced              50                      10
# 9             True           balanced              60                       2
# 10            True           balanced              60                       2
# 11            True           balanced              60                       2
# 12            True           balanced              60                       5
# 13            True           balanced              60                       5
# 14            True           balanced              60                       5
# 15            True           balanced              60                      10
# 16            True           balanced              60                      10
# 17            True           balanced              60                      10
# 18            True           balanced              70                       2
# 19            True           balanced              70                       2
# 20            True           balanced              70                       2
# 21            True           balanced              70                       5
# 22            True           balanced              70                       5
# 23            True           balanced              70                       5
# 24            True           balanced              70                      10
# 25            True           balanced              70                      10
# 26            True           balanced              70                      10
# 27           False           balanced              50                       2
# 28           False           balanced              50                       2
# 29           False           balanced              50                       2
# 30           False           balanced              50                       5
# 31           False           balanced              50                       5
# 32           False           balanced              50                       5
# 33           False           balanced              50                      10
# 34           False           balanced              50                      10
# 35           False           balanced              50                      10
# 36           False           balanced              60                       2
# 37           False           balanced              60                       2
# 38           False           balanced              60                       2
# 39           False           balanced              60                       5
# 40           False           balanced              60                       5
# 41           False           balanced              60                       5
# 42           False           balanced              60                      10
# 43           False           balanced              60                      10
# 44           False           balanced              60                      10
# 45           False           balanced              70                       2
# 46           False           balanced              70                       2
# 47           False           balanced              70                       2
# 48           False           balanced              70                       5
# 49           False           balanced              70                       5
# 50           False           balanced              70                       5
# 51           False           balanced              70                      10
# 52           False           balanced              70                      10
# 53           False           balanced              70                      10
#
#    param_n_estimators                                             params  \
# 0                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 1                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 2                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 3                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 4                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 5                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 6                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 7                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 8                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 9                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 10                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 11                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 12                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 13                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 14                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 15                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 16                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 17                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 18                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 19                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 20                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 21                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 22                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 23                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 24                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 25                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 26                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 27                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 28                100  {'bootstrap': False, 'class_weight': 'balanced...
# 29                200  {'bootstrap': False, 'class_weight': 'balanced...
# 30                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 31                100  {'bootstrap': False, 'class_weight': 'balanced...
# 32                200  {'bootstrap': False, 'class_weight': 'balanced...
# 33                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 34                100  {'bootstrap': False, 'class_weight': 'balanced...
# 35                200  {'bootstrap': False, 'class_weight': 'balanced...
# 36                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 37                100  {'bootstrap': False, 'class_weight': 'balanced...
# 38                200  {'bootstrap': False, 'class_weight': 'balanced...
# 39                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 40                100  {'bootstrap': False, 'class_weight': 'balanced...
# 41                200  {'bootstrap': False, 'class_weight': 'balanced...
# 42                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 43                100  {'bootstrap': False, 'class_weight': 'balanced...
# 44                200  {'bootstrap': False, 'class_weight': 'balanced...
# 45                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 46                100  {'bootstrap': False, 'class_weight': 'balanced...
# 47                200  {'bootstrap': False, 'class_weight': 'balanced...
# 48                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 49                100  {'bootstrap': False, 'class_weight': 'balanced...
# 50                200  {'bootstrap': False, 'class_weight': 'balanced...
# 51                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 52                100  {'bootstrap': False, 'class_weight': 'balanced...
# 53                200  {'bootstrap': False, 'class_weight': 'balanced...
#
#          ...         split3_test_score  mean_test_score  std_test_score  \
# 0        ...                  0.721212         0.694949        0.015971
# 1        ...                  0.713131         0.704545        0.005954
# 2        ...                  0.729293         0.719192        0.012205
# 3        ...                  0.696970         0.690404        0.013804
# 4        ...                  0.735354         0.706566        0.024047
# 5        ...                  0.723232         0.726263        0.009529
# 6        ...                  0.688889         0.678283        0.008002
# 7        ...                  0.713131         0.709091        0.010785
# 8        ...                  0.701010         0.713131        0.008206
# 9        ...                  0.715152         0.685354        0.025609
# 10       ...                  0.723232         0.697980        0.014742
# 11       ...                  0.723232         0.717172        0.008689
# 12       ...                  0.727273         0.704040        0.022519
# 13       ...                  0.725253         0.707576        0.011100
# 14       ...                  0.729293         0.720202        0.006468
# 15       ...                  0.696970         0.683838        0.025454
# 16       ...                  0.713131         0.709091        0.007142
# 17       ...                  0.721212         0.722222        0.007889
# 18       ...                  0.709091         0.694444        0.012153
# 19       ...                  0.715152         0.702525        0.011984
# 20       ...                  0.733333         0.717677        0.010038
# 21       ...                  0.682828         0.685859        0.007759
# 22       ...                  0.719192         0.703535        0.022009
# 23       ...                  0.713131         0.718687        0.009728
# 24       ...                  0.703030         0.695960        0.009948
# 25       ...                  0.723232         0.708081        0.015550
# 26       ...                  0.733333         0.711616        0.016497
# 27       ...                  0.721212         0.717677        0.003607
# 28       ...                  0.733333         0.745960        0.013122
# 29       ...                  0.763636         0.758586        0.007354
# 30       ...                  0.737374         0.725758        0.007609
# 31       ...                  0.759596         0.739394        0.018735
# 32       ...                  0.767677         0.756061        0.012068
# 33       ...                  0.743434         0.729798        0.014096
# 34       ...                  0.735354         0.741414        0.004285
# 35       ...                  0.741414         0.750505        0.011293
# 36       ...                  0.759596         0.730808        0.021158
# 37       ...                  0.741414         0.739899        0.006288
# 38       ...                  0.745455         0.746465        0.009529
# 39       ...                  0.739394         0.736869        0.009832
# 40       ...                  0.743434         0.725253        0.015319
# 41       ...                  0.757576         0.757071        0.007873
# 42       ...                  0.747475         0.715152        0.020252
# 43       ...                  0.761616         0.742424        0.018870
# 44       ...                  0.723232         0.737374        0.017082
# 45       ...                  0.743434         0.726263        0.015811
# 46       ...                  0.747475         0.738384        0.011561
# 47       ...                  0.743434         0.749495        0.006227
# 48       ...                  0.719192         0.729798        0.010038
# 49       ...                  0.743434         0.752525        0.007354
# 50       ...                  0.759596         0.751515        0.010785
# 51       ...                  0.723232         0.725758        0.014940
# 52       ...                  0.745455         0.735859        0.008128
# 53       ...                  0.751515         0.749495        0.003779
#
#     rank_test_score  split0_train_score  split1_train_score  \
# 0                48                 1.0                 1.0
# 1                42                 1.0                 1.0
# 2                29                 1.0                 1.0
# 3                50                 1.0                 1.0
# 4                41                 1.0                 1.0
# 5                22                 1.0                 1.0
# 6                54                 1.0                 1.0
# 7                37                 1.0                 1.0
# 8                35                 1.0                 1.0
# 9                52                 1.0                 1.0
# 10               46                 1.0                 1.0
# 11               33                 1.0                 1.0
# 12               43                 1.0                 1.0
# 13               40                 1.0                 1.0
# 14               28                 1.0                 1.0
# 15               53                 1.0                 1.0
# 16               37                 1.0                 1.0
# 17               27                 1.0                 1.0
# 18               49                 1.0                 1.0
# 19               45                 1.0                 1.0
# 20               31                 1.0                 1.0
# 21               51                 1.0                 1.0
# 22               44                 1.0                 1.0
# 23               30                 1.0                 1.0
# 24               47                 1.0                 1.0
# 25               39                 1.0                 1.0
# 26               36                 1.0                 1.0
# 27               31                 1.0                 1.0
# 28               10                 1.0                 1.0
# 29                1                 1.0                 1.0
# 30               24                 1.0                 1.0
# 31               14                 1.0                 1.0
# 32                3                 1.0                 1.0
# 33               20                 1.0                 1.0
# 34               12                 1.0                 1.0
# 35                6                 1.0                 1.0
# 36               19                 1.0                 1.0
# 37               13                 1.0                 1.0
# 38                9                 1.0                 1.0
# 39               17                 1.0                 1.0
# 40               26                 1.0                 1.0
# 41                2                 1.0                 1.0
# 42               34                 1.0                 1.0
# 43               11                 1.0                 1.0
# 44               16                 1.0                 1.0
# 45               22                 1.0                 1.0
# 46               15                 1.0                 1.0
# 47                7                 1.0                 1.0
# 48               20                 1.0                 1.0
# 49                4                 1.0                 1.0
# 50                5                 1.0                 1.0
# 51               24                 1.0                 1.0
# 52               18                 1.0                 1.0
# 53                7                 1.0                 1.0
#
#     split2_train_score  split3_train_score  mean_train_score  std_train_score
# 0             1.000000                 1.0          1.000000         0.000000
# 1             1.000000                 1.0          1.000000         0.000000
# 2             1.000000                 1.0          1.000000         0.000000
# 3             1.000000                 1.0          1.000000         0.000000
# 4             1.000000                 1.0          1.000000         0.000000
# 5             1.000000                 1.0          1.000000         0.000000
# 6             0.999327                 1.0          0.999832         0.000292
# 7             1.000000                 1.0          1.000000         0.000000
# 8             1.000000                 1.0          1.000000         0.000000
# 9             1.000000                 1.0          1.000000         0.000000
# 10            1.000000                 1.0          1.000000         0.000000
# 11            1.000000                 1.0          1.000000         0.000000
# 12            1.000000                 1.0          1.000000         0.000000
# 13            1.000000                 1.0          1.000000         0.000000
# 14            1.000000                 1.0          1.000000         0.000000
# 15            1.000000                 1.0          1.000000         0.000000
# 16            1.000000                 1.0          1.000000         0.000000
# 17            1.000000                 1.0          1.000000         0.000000
# 18            1.000000                 1.0          1.000000         0.000000
# 19            1.000000                 1.0          1.000000         0.000000
# 20            1.000000                 1.0          1.000000         0.000000
# 21            1.000000                 1.0          1.000000         0.000000
# 22            1.000000                 1.0          1.000000         0.000000
# 23            1.000000                 1.0          1.000000         0.000000
# 24            1.000000                 1.0          1.000000         0.000000
# 25            1.000000                 1.0          1.000000         0.000000
# 26            1.000000                 1.0          1.000000         0.000000
# 27            1.000000                 1.0          1.000000         0.000000
# 28            1.000000                 1.0          1.000000         0.000000
# 29            1.000000                 1.0          1.000000         0.000000
# 30            1.000000                 1.0          1.000000         0.000000
# 31            1.000000                 1.0          1.000000         0.000000
# 32            1.000000                 1.0          1.000000         0.000000
# 33            1.000000                 1.0          1.000000         0.000000
# 34            1.000000                 1.0          1.000000         0.000000
# 35            1.000000                 1.0          1.000000         0.000000
# 36            1.000000                 1.0          1.000000         0.000000
# 37            1.000000                 1.0          1.000000         0.000000
# 38            1.000000                 1.0          1.000000         0.000000
# 39            1.000000                 1.0          1.000000         0.000000
# 40            1.000000                 1.0          1.000000         0.000000
# 41            1.000000                 1.0          1.000000         0.000000
# 42            1.000000                 1.0          1.000000         0.000000
# 43            1.000000                 1.0          1.000000         0.000000
# 44            1.000000                 1.0          1.000000         0.000000
# 45            1.000000                 1.0          1.000000         0.000000
# 46            1.000000                 1.0          1.000000         0.000000
# 47            1.000000                 1.0          1.000000         0.000000
# 48            1.000000                 1.0          1.000000         0.000000
# 49            1.000000                 1.0          1.000000         0.000000
# 50            1.000000                 1.0          1.000000         0.000000
# 51            1.000000                 1.0          1.000000         0.000000
# 52            1.000000                 1.0          1.000000         0.000000
# 53            1.000000                 1.0          1.000000         0.000000
#
# [54 rows x 23 columns]

# %% [markdown]
# ### Predict

# %%
y_pred = gs.predict(X_test)

# %%
print("Best hyperparameters: {}".format(gs.best_params_))
print("Best accuracy score: {:3f}".format(gs.best_score_))
# Out:
# Best hyperparameters: {'bootstrap': False, 'class_weight': 'balanced', 'max_depth': 50, 'min_samples_split': 2, 'n_estimators': 200}
# Best accuracy score: 0.758586

# %% [markdown]
# ### Report

# %%
print("Classification report for - \n{}:\n{}\n".format(gs, metrics.classification_report(y_test, y_pred)))
# Out:
# Classification report for -
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=31, shuffle=True),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [50, 100, 200], 'max_depth': [50, 60, 70], 'min_samples_split': [2, 5, 10], 'bootstrap': [True, False], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='accuracy', verbose=3):
#                          precision    recall  f1-score   support
#
# Genuine Genuine Forgery       0.62      0.86      0.72       480
# Genuine Genuine Genuine       0.66      0.33      0.44       384
#
#             avg / total       0.63      0.63      0.60       864

# %%
# End point
end_time = time.time()

uptime = end_time - start_time

human_uptime = datetime.timedelta(seconds=uptime)

print("End time: ", datetime.datetime.now())
print("Uptime :" ,human_uptime)
# Out:
# End time:  2019-01-14 08:36:07.980338
# Uptime : 1:09:41.502698
