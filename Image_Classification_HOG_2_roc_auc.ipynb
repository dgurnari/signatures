# %% [markdown]
# # Image Classification

# %% [markdown]
# ## Libraries

# %%
import time
import datetime
import pickle
import numpy as np
from sklearn import svm, metrics
from sklearn.model_selection import StratifiedKFold,GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from pandas import DataFrame

# %% [markdown]
# ## Loading Dataset from the pickle

# %%
# Start point
start_time = time.time()
print("Start time: ", datetime.datetime.now())
# Out:
# Start time:  2019-01-16 11:31:07.510567

# %%
pickle_in = open("Signature_Dataset_HOG_110_2_int.pickle","rb")
image_dataset = pickle.load(pickle_in)

# %% [markdown]
# ## Split data in Training Set and Testing Set

# %%
X_train = image_dataset.X_train
X_test = image_dataset.X_test
y_train = image_dataset.y_train
y_test = image_dataset.y_test

print("----Dataset Loaded From Pickle----")
# Out:
# ----Dataset Loaded From Pickle----

# %% [markdown]
# ## Train data with parameter optimization

# %%
#Dictionary of models and hyperparameters

models_and_hyperparameters={'LR':(LogisticRegression(),{'C': [0.01, 0.05, 0.1, 0.5, 1, 2],
                                                        'penalty': ['l1', 'l2'], 
                                                        'class_weight': ['balanced']}),
                           'SVM':(svm.SVC(),{'C': [1, 10, 100, 1000],
                                             'gamma': [0.001, 0.0001],
                                             'kernel': ['rbf'],
                                             'class_weight': ['balanced']}),
                           'RFC':(RandomForestClassifier(), {'n_estimators': [50,100,200],
                                                             # 'max_features': ['auto', 'sqrt'],
                                                             'max_depth': [50,60,70],
                                                             'min_samples_split': [2,5,10],
                                                             #'min_samples_leaf': [1,2],
                                                             'bootstrap': [True, False],
                                                             'class_weight': ['balanced']})
                           }

# %% [markdown]
# # Logistic Regression

# %%
#LOGISTIC REGRESSION

print("----Training----")

k_fold = StratifiedKFold(n_splits=10, shuffle=True, random_state=31)

model = models_and_hyperparameters['LR'][0]
hyperparameters = models_and_hyperparameters['LR'][1]

gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='roc_auc',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
# Out:
# ----Training----
# Fitting 10 folds for each of 12 candidates, totalling 120 fits
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.7s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.6s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.5s remaining:    0.0s
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.6s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.6s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.6s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.6s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.8s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.7s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.7s
# [CV] C=0.01, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l1, score=0.5, total=   0.7s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.7090909090909091, total=   1.6s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.7094582185491276, total=   1.9s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6968778696051423, total=   1.8s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.7122130394857668, total=   1.8s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6885215794306703, total=   1.8s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.716712580348944, total=   1.8s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.7226813590449954, total=   1.6s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.6955004591368227, total=   1.6s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.686317722681359, total=   1.8s
# [CV] C=0.01, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.01, class_weight=balanced, penalty=l2, score=0.721028466483012, total=   1.6s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.6088154269972452, total=   0.8s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5415059687786961, total=   0.9s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5959595959595959, total=   0.9s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5857667584940311, total=   0.8s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.49765840220385676, total=   0.8s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.604775022956841, total=   0.9s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.6447199265381083, total=   0.8s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.6035812672176308, total=   0.8s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.5112029384756658, total=   0.8s
# [CV] C=0.05, class_weight=balanced, penalty=l1 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l1, score=0.6224977043158861, total=   0.8s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.7213957759412304, total=   2.5s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.7395775941230487, total=   2.5s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.6922865013774104, total=   2.6s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.7308539944903581, total=   2.6s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.7499540863177228, total=   2.5s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.756932966023875, total=   2.5s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.7378328741965106, total=   2.4s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.7021120293847566, total=   2.5s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.7090909090909091, total=   2.5s
# [CV] C=0.05, class_weight=balanced, penalty=l2 .......................
# [CV]  C=0.05, class_weight=balanced, penalty=l2, score=0.732415059687787, total=   2.5s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.7041322314049586, total=   1.0s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.636179981634527, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.6352617079889807, total=   1.0s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.655463728191001, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.5601469237832875, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.6641873278236915, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.6720844811753902, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.7064279155188247, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.621028466483012, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l1, score=0.6878787878787879, total=   0.9s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7214876033057851, total=   3.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7403122130394858, total=   3.4s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.6898989898989899, total=   3.4s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7330578512396695, total=   3.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7573921028466484, total=   3.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7607897153351698, total=   3.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7398530762167127, total=   3.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.698714416896235, total=   3.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7101928374655647, total=   3.2s
# [CV] C=0.1, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.1, class_weight=balanced, penalty=l2, score=0.7338842975206612, total=   3.2s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6837465564738293, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6869605142332416, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6659320477502295, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.7416896235078053, total=   1.2s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6808999081726355, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6717171717171718, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.7216712580348944, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6393021120293848, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6629017447199265, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l1 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l1, score=0.6998163452708906, total=   1.1s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.717263544536272, total=   4.4s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.7346189164370983, total=   3.9s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.6837465564738292, total=   3.8s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.7282828282828282, total=   3.9s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.769146005509642, total=   3.8s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.7641873278236914, total=   3.9s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.7404040404040404, total=   3.9s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.692929292929293, total=   3.8s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.7131313131313132, total=   3.8s
# [CV] C=0.5, class_weight=balanced, penalty=l2 ........................
# [CV]  C=0.5, class_weight=balanced, penalty=l2, score=0.7337924701561065, total=   3.8s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6815426997245179, total=   1.3s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6679522497704317, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6395775941230487, total=   1.1s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.7434343434343434, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6912764003673094, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6804407713498624, total=   1.1s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.7166207529843893, total=   1.1s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6337006427915519, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6525252525252525, total=   1.1s
# [CV] C=1, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l1, score=0.6989898989898989, total=   1.2s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.7148760330578513, total=   4.8s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.7328741965105601, total=   4.7s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.6815426997245179, total=   4.8s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.7276400367309459, total=   4.6s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.769880624426079, total=   4.8s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.7629935720844812, total=   4.8s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.740495867768595, total=   4.6s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.6905417814508724, total=   4.6s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.7130394857667585, total=   4.7s
# [CV] C=1, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=1, class_weight=balanced, penalty=l2, score=0.7356290174471992, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.6900826446280993, total=   1.2s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.6517906336088155, total=   1.2s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.6308539944903582, total=   1.1s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.7337006427915519, total=   1.1s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.6920110192837466, total=   1.2s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.6838383838383838, total=   1.1s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.7055096418732782, total=   1.3s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.6376492194674013, total=   1.2s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.6510560146923783, total=   1.1s
# [CV] C=2, class_weight=balanced, penalty=l1 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l1, score=0.7064279155188246, total=   1.3s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7143250688705235, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7312213039485767, total=   4.7s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.6806244260789717, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7265381083562903, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7699724517906337, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7631772268135903, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7384756657483931, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.6892561983471075, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7140495867768596, total=   4.8s
# [CV] C=2, class_weight=balanced, penalty=l2 ..........................
# [CV]  C=2, class_weight=balanced, penalty=l2, score=0.7353535353535354, total=   4.8s
# [Parallel(n_jobs=1)]: Done 120 out of 120 | elapsed:  4.7min finished
# ----Training Ended----

# %%
DataFrame(gs.cv_results_)
# Out:
#     mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0        0.677820         0.009528         0.500000          0.500000    0.01
# 1        1.711092         0.008939         0.705840          0.985044    0.01
# 2        0.822581         0.008945         0.581648          0.612603    0.05
# 3        2.510007         0.009104         0.727245          0.999985    0.05
# 4        0.925438         0.008947         0.654279          0.728097     0.1
# 5        3.219833         0.009413         0.728558          1.000000     0.1
# 6        1.090583         0.008933         0.685464          0.996418     0.5
# 7        3.888121         0.008892         0.727750          1.000000     0.5
# 8        1.136910         0.008932         0.680606          1.000000       1
# 9        4.715721         0.008895         0.726951          1.000000       1
# 10       1.174981         0.008955         0.678292          1.000000       2
# 11       4.781560         0.008870         0.726299          1.000000       2
#
#    param_class_weight param_penalty  \
# 0            balanced            l1
# 1            balanced            l2
# 2            balanced            l1
# 3            balanced            l2
# 4            balanced            l1
# 5            balanced            l2
# 6            balanced            l1
# 7            balanced            l2
# 8            balanced            l1
# 9            balanced            l2
# 10           balanced            l1
# 11           balanced            l2
#
#                                                params  rank_test_score  \
# 0   {'C': 0.01, 'class_weight': 'balanced', 'penal...               12
# 1   {'C': 0.01, 'class_weight': 'balanced', 'penal...                6
# 2   {'C': 0.05, 'class_weight': 'balanced', 'penal...               11
# 3   {'C': 0.05, 'class_weight': 'balanced', 'penal...                3
# 4   {'C': 0.1, 'class_weight': 'balanced', 'penalt...               10
# 5   {'C': 0.1, 'class_weight': 'balanced', 'penalt...                1
# 6   {'C': 0.5, 'class_weight': 'balanced', 'penalt...                7
# 7   {'C': 0.5, 'class_weight': 'balanced', 'penalt...                2
# 8   {'C': 1, 'class_weight': 'balanced', 'penalty'...                8
# 9   {'C': 1, 'class_weight': 'balanced', 'penalty'...                4
# 10  {'C': 2, 'class_weight': 'balanced', 'penalty'...                9
# 11  {'C': 2, 'class_weight': 'balanced', 'penalty'...                5
#
#     split0_test_score       ...         split7_test_score  split7_train_score  \
# 0            0.500000       ...                  0.500000            0.500000
# 1            0.709091       ...                  0.695500            0.985170
# 2            0.608815       ...                  0.603581            0.601626
# 3            0.721396       ...                  0.702112            1.000000
# 4            0.704132       ...                  0.706428            0.726941
# 5            0.721488       ...                  0.698714            1.000000
# 6            0.683747       ...                  0.639302            0.996742
# 7            0.717264       ...                  0.692929            1.000000
# 8            0.681543       ...                  0.633701            1.000000
# 9            0.714876       ...                  0.690542            1.000000
# 10           0.690083       ...                  0.637649            1.000000
# 11           0.714325       ...                  0.689256            1.000000
#
#     split8_test_score  split8_train_score  split9_test_score  \
# 0            0.500000            0.500000           0.500000
# 1            0.686318            0.985660           0.721028
# 2            0.511203            0.617794           0.622498
# 3            0.709091            0.999998           0.732415
# 4            0.621028            0.729782           0.687879
# 5            0.710193            1.000000           0.733884
# 6            0.662902            0.996333           0.699816
# 7            0.713131            1.000000           0.733792
# 8            0.652525            1.000000           0.698990
# 9            0.713039            1.000000           0.735629
# 10           0.651056            1.000000           0.706428
# 11           0.714050            1.000000           0.735354
#
#     split9_train_score  std_fit_time  std_score_time  std_test_score  \
# 0             0.500000      0.048030        0.001429        0.000000
# 1             0.985814      0.122934        0.000086        0.012510
# 2             0.596533      0.028789        0.000083        0.046098
# 3             0.999992      0.063607        0.000652        0.019795
# 4             0.725248      0.024421        0.000081        0.041721
# 5             1.000000      0.080889        0.000949        0.022264
# 6             0.996322      0.032679        0.000061        0.028133
# 7             1.000000      0.171257        0.000078        0.025996
# 8             1.000000      0.058563        0.000055        0.032449
# 9             1.000000      0.072102        0.000071        0.026764
# 10            1.000000      0.048649        0.000106        0.032104
# 11            1.000000      0.026898        0.000087        0.026970
#
#     std_train_score
# 0      0.000000e+00
# 1      8.120014e-04
# 2      1.033102e-02
# 3      1.855346e-05
# 4      4.020678e-03
# 5      0.000000e+00
# 6      2.730590e-04
# 7      0.000000e+00
# 8      6.802027e-07
# 9      0.000000e+00
# 10     0.000000e+00
# 11     0.000000e+00
#
# [12 rows x 33 columns]

# %%
# Creation of the pickle which is goig to store the model.

pickle_out = open("LR_roc_auc_HOG_2.pickle","wb") #Modify with the name of the dataset you're saving
pickle.dump(gs.cv_results_, pickle_out)
pickle_out.close()

print("----Pickle created----")
# Out:
# ----Pickle created----

# %% [markdown]
# ### Predict

# %%
y_pred = gs.predict(X_test)

# %%
print("Best hyperparameters: {}".format(gs.best_params_))
print("Best roc_auc score: {:3f}".format(gs.best_score_))
# Out:
# Best hyperparameters: {'C': 0.1, 'class_weight': 'balanced', 'penalty': 'l2'}
# Best roc_auc score: 0.728558

# %% [markdown]
# ### Report

# %%
print("Classification report for - \n{}:\n{}\n".format(gs, metrics.classification_report(y_test, y_pred)))
# Out:
# Classification report for -
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=31, shuffle=True),
#        error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [0.01, 0.05, 0.1, 0.5, 1, 2], 'penalty': ['l1', 'l2'], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=3):
#              precision    recall  f1-score   support
#
#          -1       0.61      0.59      0.60       480
#           1       0.56      0.59      0.57       432
#
# avg / total       0.59      0.59      0.59       912

# %% [markdown]
# \\
# \\
# \\
# \\
# \\
# # SVM

# %%
# SVM

print("----Training----")

k_fold = StratifiedKFold(n_splits=4, shuffle=True, random_state=31)

model = models_and_hyperparameters['SVM'][0]
hyperparameters = models_and_hyperparameters['SVM'][1]

gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='roc_auc',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
# Out:
# ----Training----
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6675806451612903, total= 3.3min
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  5.8min remaining:    0.0s
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.65366568914956, total= 3.3min
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed: 11.6min remaining:    0.0s
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6483327199116673, total= 3.4min
# [CV] C=1, class_weight=balanced, gamma=0.001, kernel=rbf .............
# [CV]  C=1, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.6789547294810453, total= 3.3min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5567741935483872, total= 3.3min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.555733137829912, total= 3.3min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5578505704821494, total= 3.3min
# [CV] C=1, class_weight=balanced, gamma=0.0001, kernel=rbf ............
# [CV]  C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.5848656606551343, total= 3.3min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8312023460410557, total= 3.2min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8508064516129032, total= 3.2min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.861612072138388, total= 3.2min
# [CV] C=10, class_weight=balanced, gamma=0.001, kernel=rbf ............
# [CV]  C=10, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8270445344129553, total= 3.3min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6497360703812316, total= 3.1min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6634310850439883, total= 3.1min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6454324622745675, total= 3.1min
# [CV] C=10, class_weight=balanced, gamma=0.0001, kernel=rbf ...........
# [CV]  C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.6716672800883328, total= 3.1min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8312023460410557, total= 3.2min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8514222873900295, total= 3.2min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8612587412587412, total= 3.2min
# [CV] C=100, class_weight=balanced, gamma=0.001, kernel=rbf ...........
# [CV]  C=100, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8276186970923812, total= 3.3min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.719398826979472, total= 3.1min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.7597360703812317, total= 3.1min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.7579683474420318, total= 3.1min
# [CV] C=100, class_weight=balanced, gamma=0.0001, kernel=rbf ..........
# [CV]  C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.7294074346705925, total= 3.1min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8312023460410557, total= 3.2min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8514222873900295, total= 3.2min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8612587412587412, total= 3.2min
# [CV] C=1000, class_weight=balanced, gamma=0.001, kernel=rbf ..........
# [CV]  C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, score=0.8276186970923812, total= 3.3min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.7187536656891496, total= 3.1min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.7621847507331377, total= 3.1min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.7585866764814133, total= 3.1min
# [CV] C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf .........
# [CV]  C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, score=0.7299668752300331, total= 3.1min
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed: 179.4min finished
# ----Training Ended----

# %%
DataFrame(gs.cv_results_)
# Out:
#    mean_fit_time  mean_score_time  mean_test_score  mean_train_score param_C  \
# 0     146.826307        51.460305         0.662132          0.945796       1
# 1     146.233172        51.089052         0.563799          0.754103       1
# 2     145.785899        49.023252         0.842665          1.000000      10
# 3     138.622670        47.962976         0.657566          0.927154      10
# 4     145.801156        49.043213         0.842874          1.000000     100
# 5     142.107442        43.296240         0.741626          0.999999     100
# 6     145.783166        49.049437         0.842874          1.000000    1000
# 7     143.194240        43.286253         0.742371          1.000000    1000
#
#   param_class_weight param_gamma param_kernel  \
# 0           balanced       0.001          rbf
# 1           balanced      0.0001          rbf
# 2           balanced       0.001          rbf
# 3           balanced      0.0001          rbf
# 4           balanced       0.001          rbf
# 5           balanced      0.0001          rbf
# 6           balanced       0.001          rbf
# 7           balanced      0.0001          rbf
#
#                                               params  rank_test_score  \
# 0  {'C': 1, 'class_weight': 'balanced', 'gamma': ...                6
# 1  {'C': 1, 'class_weight': 'balanced', 'gamma': ...                8
# 2  {'C': 10, 'class_weight': 'balanced', 'gamma':...                3
# 3  {'C': 10, 'class_weight': 'balanced', 'gamma':...                7
# 4  {'C': 100, 'class_weight': 'balanced', 'gamma'...                1
# 5  {'C': 100, 'class_weight': 'balanced', 'gamma'...                5
# 6  {'C': 1000, 'class_weight': 'balanced', 'gamma...                1
# 7  {'C': 1000, 'class_weight': 'balanced', 'gamma...                4
#
#         ...         split1_test_score  split1_train_score  split2_test_score  \
# 0       ...                  0.653666            0.940606           0.648333
# 1       ...                  0.555733            0.740624           0.557851
# 2       ...                  0.850806            1.000000           0.861612
# 3       ...                  0.663431            0.921055           0.645432
# 4       ...                  0.851422            1.000000           0.861259
# 5       ...                  0.759736            0.999998           0.757968
# 6       ...                  0.851422            1.000000           0.861259
# 7       ...                  0.762185            1.000000           0.758587
#
#    split2_train_score  split3_test_score  split3_train_score  std_fit_time  \
# 0            0.941247           0.678955            0.954987      1.152600
# 1            0.753990           0.584866            0.756214      0.155792
# 2            1.000000           0.827045            1.000000      0.095257
# 3            0.924170           0.671667            0.935883      0.718764
# 4            1.000000           0.827619            1.000000      0.106188
# 5            1.000000           0.729407            1.000000      0.182213
# 6            1.000000           0.827619            1.000000      0.091702
# 7            1.000000           0.729967            1.000000      0.689200
#
#    std_score_time  std_test_score  std_train_score
# 0        1.288901        0.011984     5.753180e-03
# 1        0.025150        0.012178     8.915632e-03
# 2        0.134472        0.014145     0.000000e+00
# 3        0.360785        0.010506     5.532233e-03
# 4        0.155340        0.013961     0.000000e+00
# 5        0.328031        0.017598     8.167933e-07
# 6        0.148445        0.013961     0.000000e+00
# 7        0.306349        0.018491     0.000000e+00
#
# [8 rows x 22 columns]

# %%
# Creation of the pickle which is goig to store the model.

pickle_out = open("SVM_roc_auc_HOG_2.pickle","wb") #Modify with the name of the dataset you're saving
pickle.dump(gs.cv_results_, pickle_out)
pickle_out.close()

print("----Pickle created----")
# Out:
# ----Pickle created----

# %% [markdown]
# ### Predict

# %%
y_pred = gs.predict(X_test)

# %%
print("Best hyperparameters: {}".format(gs.best_params_))
print("Best roc_auc score: {:3f}".format(gs.best_score_))
# Out:
# Best hyperparameters: {'C': 100, 'class_weight': 'balanced', 'gamma': 0.001, 'kernel': 'rbf'}
# Best roc_auc score: 0.842874

# %% [markdown]
# ### Report

# %%
print("Classification report for - \n{}:\n{}\n".format(gs, metrics.classification_report(y_test, y_pred)))
# Out:
# Classification report for -
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=31, shuffle=True),
#        error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf'], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=3):
#              precision    recall  f1-score   support
#
#          -1       0.61      0.65      0.63       480
#           1       0.58      0.55      0.56       432
#
# avg / total       0.60      0.60      0.60       912

# %% [markdown]
# //
# //
# //
# //
# //
#
# # Random Forest

# %%
#RANDOM FOREST

print("----Training----")

k_fold = StratifiedKFold(n_splits=4, shuffle=True, random_state=31)

model = models_and_hyperparameters['RFC'][0]
hyperparameters = models_and_hyperparameters['RFC'][1]

gs = GridSearchCV(model, 
                   param_grid = hyperparameters,
                   cv=k_fold, 
                   scoring='roc_auc',
                   verbose=3,
                   return_train_score=True)

gs.fit(X_train, y_train)

print("----Training Ended----")
# Out:
# ----Training----
# Fitting 4 folds for each of 54 candidates, totalling 216 fits
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.7981818181818182, total=   4.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.1s remaining:    0.0s
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.761510263929619, total=   3.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    8.2s remaining:    0.0s
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.7761280824438719, total=   4.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=50, score=0.7554876702245125, total=   3.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.8247140762463343, total=   7.5s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.7964662756598241, total=   7.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.7904600662495399, total=   7.5s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=100, score=0.7842841369157159, total=   7.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.8295674486803519, total=  14.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.8191348973607038, total=  14.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.8084136915715863, total=  14.7s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=2, n_estimators=200, score=0.7822524843577475, total=  14.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.7769574780058651, total=   4.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.7763269794721408, total=   3.7s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.776474052263526, total=   3.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=50, score=0.7794258373205742, total=   4.0s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.8155205278592376, total=   7.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.7813489736070381, total=   7.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.8076996687523004, total=   7.5s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=100, score=0.7911152005888848, total=   7.3s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.8151026392961878, total=  14.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.8087976539589442, total=  14.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.8139565697460434, total=  14.5s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=5, n_estimators=200, score=0.8077732793522265, total=  14.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.770117302052786, total=   3.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.7538123167155424, total=   3.9s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.7963930806036069, total=   3.8s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=50, score=0.7434670592565329, total=   3.8s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.8025953079178887, total=   7.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.7848826979472142, total=   7.2s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.7686124401913876, total=   7.4s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=100, score=0.7628119249171881, total=   7.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200, score=0.8125073313782992, total=  14.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200, score=0.823533724340176, total=  14.1s
# [CV] bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=200
# [CV]  bootstrap=True, class_weight=balanced, max_depth=50, min_samples_split=10, n_estimators=
# 32      22.539863         0.085868         0.848074               1.0
# 33       5.898930         0.057406         0.814655               1.0
# 34      11.357329         0.066361         0.827089               1.0
# 35      22.315144         0.085467         0.840681               1.0
# 36       6.012006         0.057539         0.811332               1.0
# 37      11.527011         0.066598         0.831407               1.0
# 38      22.854173         0.086401         0.845544               1.0
# 39       5.955191         0.057573         0.808528               1.0
# 40      11.514107         0.066696         0.837398               1.0
# 41      22.604719         0.086022         0.842712               1.0
# 42       5.852076         0.057427         0.808740               1.0
# 43      11.369636         0.066380         0.818795               1.0
# 44      22.236570         0.084747         0.837847               1.0
# 45       5.931142         0.056714         0.809479               1.0
# 46      11.529241         0.065904         0.829671               1.0
# 47      22.875527         0.085420         0.839984               1.0
# 48       5.963339         0.056952         0.807059               1.0
# 49      11.458664         0.066073         0.836579               1.0
# 50      22.662922         0.085376         0.845735               1.0
# 51       5.879248         0.056877         0.803454               1.0
# 52      11.341609         0.065686         0.830857               1.0
# 53      22.309566         0.084947         0.842962               1.0
#
#    param_bootstrap param_class_weight param_max_depth param_min_samples_split  \
# 0             True           balanced              50                       2
# 1             True           balanced              50                       2
# 2             True           balanced              50                       2
# 3             True           balanced              50                       5
# 4             True           balanced              50                       5
# 5             True           balanced              50                       5
# 6             True           balanced              50                      10
# 7             True           balanced              50                      10
# 8             True           balanced              50                      10
# 9             True           balanced              60                       2
# 10            True           balanced              60                       2
# 11            True           balanced              60                       2
# 12            True           balanced              60                       5
# 13            True           balanced              60                       5
# 14            True           balanced              60                       5
# 15            True           balanced              60                      10
# 16            True           balanced              60                      10
# 17            True           balanced              60                      10
# 18            True           balanced              70                       2
# 19            True           balanced              70                       2
# 20            True           balanced              70                       2
# 21            True           balanced              70                       5
# 22            True           balanced              70                       5
# 23            True           balanced              70                       5
# 24            True           balanced              70                      10
# 25            True           balanced              70                      10
# 26            True           balanced              70                      10
# 27           False           balanced              50                       2
# 28           False           balanced              50                       2
# 29           False           balanced              50                       2
# 30           False           balanced              50                       5
# 31           False           balanced              50                       5
# 32           False           balanced              50                       5
# 33           False           balanced              50                      10
# 34           False           balanced              50                      10
# 35           False           balanced              50                      10
# 36           False           balanced              60                       2
# 37           False           balanced              60                       2
# 38           False           balanced              60                       2
# 39           False           balanced              60                       5
# 40           False           balanced              60                       5
# 41           False           balanced              60                       5
# 42           False           balanced              60                      10
# 43           False           balanced              60                      10
# 44           False           balanced              60                      10
# 45           False           balanced              70                       2
# 46           False           balanced              70                       2
# 47           False           balanced              70                       2
# 48           False           balanced              70                       5
# 49           False           balanced              70                       5
# 50           False           balanced              70                       5
# 51           False           balanced              70                      10
# 52           False           balanced              70                      10
# 53           False           balanced              70                      10
#
#    param_n_estimators                                             params  \
# 0                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 1                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 2                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 3                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 4                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 5                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 6                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 7                 100  {'bootstrap': True, 'class_weight': 'balanced'...
# 8                 200  {'bootstrap': True, 'class_weight': 'balanced'...
# 9                  50  {'bootstrap': True, 'class_weight': 'balanced'...
# 10                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 11                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 12                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 13                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 14                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 15                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 16                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 17                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 18                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 19                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 20                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 21                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 22                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 23                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 24                 50  {'bootstrap': True, 'class_weight': 'balanced'...
# 25                100  {'bootstrap': True, 'class_weight': 'balanced'...
# 26                200  {'bootstrap': True, 'class_weight': 'balanced'...
# 27                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 28                100  {'bootstrap': False, 'class_weight': 'balanced...
# 29                200  {'bootstrap': False, 'class_weight': 'balanced...
# 30                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 31                100  {'bootstrap': False, 'class_weight': 'balanced...
# 32                200  {'bootstrap': False, 'class_weight': 'balanced...
# 33                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 34                100  {'bootstrap': False, 'class_weight': 'balanced...
# 35                200  {'bootstrap': False, 'class_weight': 'balanced...
# 36                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 37                100  {'bootstrap': False, 'class_weight': 'balanced...
# 38                200  {'bootstrap': False, 'class_weight': 'balanced...
# 39                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 40                100  {'bootstrap': False, 'class_weight': 'balanced...
# 41                200  {'bootstrap': False, 'class_weight': 'balanced...
# 42                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 43                100  {'bootstrap': False, 'class_weight': 'balanced...
# 44                200  {'bootstrap': False, 'class_weight': 'balanced...
# 45                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 46                100  {'bootstrap': False, 'class_weight': 'balanced...
# 47                200  {'bootstrap': False, 'class_weight': 'balanced...
# 48                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 49                100  {'bootstrap': False, 'class_weight': 'balanced...
# 50                200  {'bootstrap': False, 'class_weight': 'balanced...
# 51                 50  {'bootstrap': False, 'class_weight': 'balanced...
# 52                100  {'bootstrap': False, 'class_weight': 'balanced...
# 53                200  {'bootstrap': False, 'class_weight': 'balanced...
# 18        0.000133        0.017530     0.000000e+00
# 19        0.000073        0.010188     0.000000e+00
# 20        0.000178        0.013694     7.850462e-17
# 21        0.000060        0.010359     0.000000e+00
# 22        0.000132        0.010013     5.551115e-17
# 23        0.000101        0.015163     0.000000e+00
# 24        0.000118        0.018164     0.000000e+00
# 25        0.000104        0.016729     0.000000e+00
# 26        0.000070        0.011885     0.000000e+00
# 27        0.000061        0.014693     0.000000e+00
# 28        0.000174        0.011690     0.000000e+00
# 29        0.000168        0.009115     0.000000e+00
# 30        0.000119        0.014634     0.000000e+00
# 31        0.000187        0.008745     0.000000e+00
# 32        0.000204        0.014220     0.000000e+00
# 33        0.000113        0.018767     0.000000e+00
# 34        0.000114        0.010876     0.000000e+00
# 35        0.000142        0.014503     0.000000e+00
# 36        0.000039        0.011098     0.000000e+00
# 37        0.000102        0.015354     0.000000e+00
# 38        0.000230        0.016054     0.000000e+00
# 39        0.000078        0.010029     0.000000e+00
# 40        0.000160        0.012024     0.000000e+00
# 41        0.000101        0.017047     0.000000e+00
# 42        0.000176        0.018997     0.000000e+00
# 43        0.000082        0.016670     0.000000e+00
# 44        0.000337        0.011853     0.000000e+00
# 45        0.000183        0.017283     0.000000e+00
# 46        0.000104        0.010336     0.000000e+00
# 47        0.000209        0.006137     0.000000e+00
# 48        0.000184        0.012477     7.850462e-17
# 49        0.000244        0.007811     5.551115e-17
# 50        0.000244        0.010400     0.000000e+00
# 51        0.000068        0.026617     0.000000e+00
# 52        0.000198        0.016198     0.000000e+00
# 53        0.000305        0.012563     0.000000e+00
#
# [54 rows x 23 columns]

# %%
# Creation of the pickle which is goig to store the model.

pickle_out = open("RF_roc_auc_HOG_2.pickle","wb") #Modify with the name of the dataset you're saving
pickle.dump(gs.cv_results_, pickle_out)
pickle_out.close()

print("----Pickle created----")
# Out:
# ----Pickle created----

# %% [markdown]
# ## Predict

# %%
y_pred = gs.predict(X_test)

# %%
print("Best hyperparameters: {}".format(gs.best_params_))
print("Best roc_auc score: {:3f}".format(gs.best_score_))
# Out:
# Best hyperparameters: {'bootstrap': False, 'class_weight': 'balanced', 'max_depth': 50, 'min_samples_split': 2, 'n_estimators': 200}
# Best roc_auc score: 0.848984

# %% [markdown]
# ## Report

# %%
print("Classification report for - \n{}:\n{}\n".format(gs, metrics.classification_report(y_test, y_pred)))
# Out:
# Classification report for -
# GridSearchCV(cv=StratifiedKFold(n_splits=4, random_state=31, shuffle=True),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'n_estimators': [50, 100, 200], 'max_depth': [50, 60, 70], 'min_samples_split': [2, 5, 10], 'bootstrap': [True, False], 'class_weight': ['balanced']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring='roc_auc', verbose=3):
#              precision    recall  f1-score   support
#
#          -1       0.59      0.84      0.69       480
#           1       0.66      0.34      0.45       432
#
# avg / total       0.62      0.61      0.58       912

# %%
# End point
end_time = time.time()
uptime = end_time - start_time
human_uptime = datetime.timedelta(seconds=uptime)

print("End time: ", datetime.datetime.now())
print("Uptime :" ,human_uptime)
# Out:
# End time:  2019-01-16 15:23:41.745017
# Uptime : 3:52:34.234460
